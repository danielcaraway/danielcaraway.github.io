# %%
import pandas as pd
from fbprophet import Prophet 

df = pd.read_csv('https://raw.githubusercontent.com/danielcaraway/data/master/Zip_Zhvi_SingleFamilyResidence.csv', encoding='latin')

# %%
# for state in set(df['State']):
#   state_df = df[df['State'] == state]
#   state_df
#   print(state)

# %%
# m = Prophet()
# m.fit(df)
# future = m.make_future_dataframe(periods=12, freq='M')
# future.tail()

# %%
CA = df[df['State'] == 'CA']

# %%
CA.T
# Out:
#                                     13     ...                30428
# RegionID                            97564  ...                97209
# RegionName                          94109  ...                93282
# City                        San Francisco  ...               Tulare
# State                                  CA  ...                   CA
# Metro       San Francisco-Oakland-Hayward  ...  Visalia-Porterville
# ...                                   ...  ...                  ...
# 2019-08                           2653455  ...               156855
# 2019-09                           2659471  ...               156706
# 2019-10                           2673801  ...               156429
# 2019-11                           2688969  ...               155899
# 2019-12                           2717489  ...               157523
#
# [292 rows x 1685 columns]
